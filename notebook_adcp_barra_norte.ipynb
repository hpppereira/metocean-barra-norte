# %% [markdown]
# ## Processamento dos dados de ADCP da Barra Norte Campanha
# - Campanha do dia 15-07-2019
# - Henrique Pereira

# %%
from importlib import reload
import proc_adcp
reload(proc_adcp)
# Out:
# --------------------------------------------------
# Campanha completa
# --------------------------------------------------
# Dia 15
# --------------------------------------------------
# Dia 16
# --------------------------------------------------
# Dia 17
# --------------------------------------------------
# Dia 18
# --------------------------------------------------
# Dia 19
# --------------------------------------------------
# Dia 20
# --------------------------------------------------
# Dia 21
# --------------------------------------------------
# Dia 22
# --------------------------------------------------
# Dia 23
# --------------------------------------------------
# Dia 24
# --------------------------------------------------
# Dia 25
# --------------------------------------------------
# Dia 26
# --------------------------------------------------
# Campanha completa
# --------------------------------------------------
# Dia 15
# ...
